print(a4)
# Out:
# b'...='

# %%
tmp = b'...='

# %%
print(base64.b32encode(tmp))
# Out:
# b'...===='

# %%
a= '49 48 52 32 49 48 52 32 49 48 52 32 57 57 32 49 49 54 32 49 48 50 32 49 50 51 32 56 52 32 55 56 32 55 48 32 56 51 32 55 50 32 57 53 32 49 48 53 32 49 49 53 32 57 53 32 49 48 53 32 49 49 48 32 49 49 54 32 49 48 49 32 49 49 52 32 49 48 49 32 49 49 53 32 49 49 54 32 49 48 53 32 49 49 48 32 49 48 51 32 49 50 53 32'
b= a.split()
c = list()
for i in b:
  c.append(int(i)*2)

# %%
print(c)
# Out:
# [98, 96, 104, 64, 98, 96, 104, 64, 98, 96, 104, 64, 114, 114, 64, 98, 98, 108, 64, 98, 96, 100, 64, 98, 100, 102, 64, 112, 104, 64, 110, 112, 64, 110, 96, 64, 112, 102, 64, 110, 100, 64, 114, 106, 64, 98, 96, 106, 64, 98, 98, 106, 64, 114, 106, 64, 98, 96, 106, 64, 98, 98, 96, 64, 98, 98, 108, 64, 98, 96, 98, 64, 98, 98, 104, 64, 98, 96, 98, 64, 98, 98, 106, 64, 98, 98, 108, 64, 98, 96, 106, 64, 98, 98, 96, 64, 98, 96, 102, 64, 98, 100, 106, 64]

# %%
for i in c:
  print(i,end=' ')
# Out:
# 98 96 104 64 98 96 104 64 98 96 104 64 114 114 64 98 98 108 64 98 96 100 64 98 100 102 64 112 104 64 110 112 64 110 96 64 112 102 64 110 100 64 114 106 64 98 96 106 64 98 98 106 64 114 106 64 98 96 106 64 98 98 96 64 98 98 108 64 98 96 98 64 98 98 104 64 98 96 98 64 98 98 106 64 98 98 108 64 98 96 106 64 98 98 96 64 98 96 102 64 98 100 106 64

# %%
a = '==wawhnez8WesNHI4xGIU1Xc042czNXK9BTLxsnetEGK'
def reverse_slicing(s):
    return s[::-1]
print(reverse_slicing(a))
# Out:
# KGEtensxLTB9KXNzc240cX1UIGx4IHNseW8zenhwaw==

# %%
def reverse_slicing(s):
    return s[::-1]

# %%
tt = 'LLL SLSS SLSS LLL LLL SLSS SLSS LLL LLL SLSS LLL SLSS LLL SLSS LLL SLSS LLL SLSS SLSS LLL LLL SLSS LLL LLL LLL SLSS LLL LLL LLL LLL SLSS LLL LLL SLSS LLL LLL SLSS SLSS LLL SLSS LLL SLSS LLL SLSS LLL SLSS LLL SLSS LLL SLSS LLL SLSS SLSS LLL SLSS LLL LLL SLSS SLSS LLL LLL SLSS SLSS LLL LLL SLSS LLL SLSS LLL SLSS LLL LLL LLL SLSS SLSS LLL SLSS LLL SLSS SLSS LLL LLL SLSS SLSS LLL LLL LLL LLL LLL LLL SLSS SLSS LLL LLL LLL LLL LLL SLSS LLL SLSS LLL LLL SLSS LLL LLL SLSS LLL LLL LLL SLSS SLSS LLL LLL LLL SLSS SLSS SLSS LLL LLL SLSS LLL SLSS LLL LLL LLL SLSS LLL SLSS LLL SLSS LLL LLL SLSS SLSS LLL SLSS LLL SLSS LLL LLL LLL SLSS LLL SLSS LLL SLSS SLSS LLL LLL SLSS LLL LLL LLL SLSS SLSS LLL LLL SLSS SLSS LLL LLL SLSS LLL LLL SLSS SLSS SLSS LLL LLL SLSS LLL LLL LLL SLSS SLSS LLL LLL LLL SLSS SLSS SLSS LLL LLL LLL LLL LLL SLSS SLSS LLL LLL SLSS SLSS LLL SLSS LLL LLL SLSS SLSS SLSS LLL LLL SLSS LLL LLL LLL SLSS LLL SLSS LLL SLSS SLSS LLL SLSS LLL LLL LLL LLL SLSS LLL SLSS SLSS LLL LLL LLL LLL SLSS SLSS LLL LLL SLSS LLL SLSS LLL LLL SLSS SLSS LLL LLL SLSS LLL LLL SLSS LLL SLSS SLSS LLL SLSS LLL LLL LLL SLSS SLSS LLL LLL LLL LLL LLL SLSS LLL SLSS SLSS LLL LLL SLSS LLL LLL SLSS SLSS LLL LLL SLSS LLL LLL SLSS SLSS LLL SLSS LLL LLL LLL LLL SLSS SLSS LLL SLSS SLSS SLSS SLSS LLL SLSS SLSS LLL LLL LLL LLL SLSS LLL SLSS LLL LLL LLL LLL LLL SLSS LLL LLL SLSS SLSS SLSS SLSS LLL SLSS LLL LLL SLSS SLSS SLSS SLSS LLL SLSS'
ttt = tt.split()
print(ttt)
for i in ttt:
  if i == 'LLL':
    print('0',end='')
  else:
    print('1',end='')
# Out:
# ['LLL', 'SLSS', 'SLSS', 'LLL', 'LLL', 'SLSS', 'SLSS', 'LLL', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'SLSS', 'SLSS', 'LLL', 'LLL', 'SLSS', 'LLL', 'LLL', 'LLL', 'SLSS', 'LLL', 'LLL', 'LLL', 'LLL', 'SLSS', 'LLL', 'LLL', 'SLSS', 'LLL', 'LLL', 'SLSS', 'SLSS', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'SLSS', 'SLSS', 'LLL', 'SLSS', 'LLL', 'LLL', 'SLSS', 'SLSS', 'LLL', 'LLL', 'SLSS', 'SLSS', 'LLL', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'LLL', 'LLL', 'SLSS', 'SLSS', 'LLL', 'SLSS', 'LLL', 'SLSS', 'SLSS', 'LLL', 'LLL', 'SLSS', 'SLSS', 'LLL', 'LLL', 'LLL', 'LLL', 'LLL', 'LLL', 'SLSS', 'SLSS', 'LLL', 'LLL', 'LLL', 'LLL', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'LLL', 'SLSS', 'LLL', 'LLL', 'SLSS', 'LLL', 'LLL', 'LLL', 'SLSS', 'SLSS', 'LLL', 'LLL', 'LLL', 'SLSS', 'SLSS', 'SLSS', 'LLL', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'LLL', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'SLSS', 'LLL', 'LLL', 'SLSS', 'SLSS', 'L
# ...

# %%
tttt= '}GA1F_NM4D_D0G_4_74HW{ftchhh'
print(reverse_slicing(tttt))
# Out:
# hhhctf{WH47_4_G0D_D4MN_F1AG}

# %%
a='01010001 32 01000110 6C 01100011 31 01000001 33 01001111 6C 01110000 6A 01100001 6E 01011010 66 01001110 47 01111000 39 01010011 6A 01101111 77 01001101 55 00110000 30 01100100 63 01001011 33 01001110 57 00111001 74 01011000 7A 01010010 75 01100011 4D 01001011 33 01110111 72 01100100 76 01100101 31 01101111 30 01011000 7A 01001000 43 01110100 30 01101100 76 01001110 58 01011001 30 01010100 6E 01110010 43 01110100 77 00111101 3D *'

# %%
ta = a.split()

# %%
print(ta)
# Out:
# ['01010001', '32', '01000110', '6C', '01100011', '31', '01000001', '33', '01001111', '6C', '01110000', '6A', '01100001', '6E', '01011010', '66', '01001110', '47', '01111000', '39', '01010011', '6A', '01101111', '77', '01001101', '55', '00110000', '30', '01100100', '63', '01001011', '33', '01001110', '57', '00111001', '74', '01011000', '7A', '01010010', '75', '01100011', '4D', '01001011', '33', '01110111', '72', '01100100', '76', '01100101', '31', '01101111', '30', '01011000', '7A', '01001000', '43', '01110100', '30', '01101100', '76', '01001110', '58', '01011001', '30', '01010100', '6E', '01110010', '43', '01110100', '77', '00111101', '3D', '*']

# %%
scale = 16 ## equals to hexadecimal

num_of_bits = 8

a = 1
for i in ta:
  if a:
    a=0
    print(i)
  else:
    a=1
    print(bin(int(i, scale))[2:].zfill(num_of_bits))
# Out:
# 01010001
# 00110010
# 01000110
# 01101100
# 01100011
# 00110001
# 01000001
# 00110011
# 01001111
# 01101100
# 01110000
# 01101010
# 01100001
# 01101110
# 01011010
# 01100110
# 01001110
# 01000111
# 01111000
# 00111001
# 01010011
# 01101010
# 01101111
# 01110111
# 01001101
# 01010101
# 00110000
# 00110000
# 01100100
# 01100011
# 01001011
# 00110011
# 01001110
# 01010111
# 00111001
# 01110100
# 01011000
# 01111010
# 01010010
# 01110101
# 01100011
# 01001101
# 01001011
# 00110011
# 01110111
# 01110010
# 01100100
# 01110110
# 01100101
# 00110001
# 01101111
# 00110000
# 01011000
# 01111010
# 01001000
# 01000011
# 01110100
# 00110000
# 01101100
# 01110110
# 01001110
# 01011000
# 01011001
# 00110000
# 01010100
# 01101110
# 01110010
# 01000011
# 01110100
# 01110111
# 00111101
# 00111101
# *

# %%
oct(11000)
# Out:
# '0o25370'

# %%
hi = '41.25.658.665.33.05.36.653.655.94.44.662.41.25.14.661.32.05.44.658.32.94.01.668.33.32.666.93.656.35.15.15'
op = hi.split('.')
for i in op:
  print(chr(int(i)),end='')
# Out:
# )ʒʙ!$ʍʏ^,ʖ)ʕ ,ʒ ^ʜ! ʚ]ʐ#

# %% [markdown]
# # Solution

# %% [markdown]
# Base32

# %%
import base64
abc = b'...===='
abc_1 = base64.b32decode(abc)
abc_1
# Out:
# b'...='

# %% [markdown]
# Base32

# %%
abc_2 = base64.b32decode(abc_1)
abc_2
# Out:
# b'84 107 74 86 82 49 70 90 77 49 86 78 87 106 86 88 78 106 82 69 85 48 56 49 85 49 99 50 77 108 82 88 84 48 111 122 86 48 116 97 84 69 90 78 82 108 70 88 81 49 108 77 82 48 48 49 86 70 104 84 78 85 82 68 85 69 90 97 83 69 100 97 84 70 82 80 84 108 112 73 82 122 82 85 86 85 57 97 86 107 104 84 78 85 82 76 85 69 90 84 83 69 107 49 77 49 100 80 85 106 78 73 85 122 86 69 85 48 57 97 85 86 82 66 78 70 82 86 84 86 85 121 86 69 78 79 84 70 78 78 86 106 74 72 83 122 86 69 82 108 66 71 87 108 100 76 78 70 82 85 85 69 90 97 86 48 115 48 86 70 112 80 85 108 82 88 84 84 82 85 87 69 49 87 87 107 104 80 87 107 82 83 84 48 90 90 87 69 56 48 86 70 112 80 83 108 86 73 84 122 100 74 80 81 61 61'

# %% [markdown]
# Ascii to string

# %%
abc_3 = str(abc_2,'utf-8')
abc_4 = str()
for i in abc_3.split(' '):
  abc_4 += chr(int(i))
abc_4
# Out:
# 'TkJVR1FZM1VNWjVXNjREU081U1c2MlRXT0ozV0taTEZNRlFXQ1lMR001VFhTNURDUEZaSEdaTFRPTlpIRzRUVU9aVkhTNURLUEZTSEk1M1dPUjNIUzVEU09aUVRBNFRVTVUyVENOTFNNVjJHSzVERlBGWldLNFRUUEZaV0s0VFpPUlRXTTRUWE1WWkhPWkRST0ZZWE80VFpPSlVITzdJPQ=='

# %% [markdown]
# Base64

# %%
abc_5 = base64.b64decode(abc_4)
abc_5
# Out:
# b'NBUGQY3UMZ5W64DSO5SW62TWOJ3WKZLFMFQWCYLGM5TXS5DCPFZHGZLTONZHG4TUOZVHS5DKPFSHI53WOR3HS5DSOZQTA4TUMU2TCNLSMV2GK5DFPFZWK4TTPFZWK4TZORTWM4TXMVZHOZDROFYXO4TZOJUHO7I='

# %% [markdown]
# Base32

# %%
abc_6 = base64.b32decode(abc_5)
abc_6
# Out:
# b'hhhctf{oprweojvrweeeaaaafggytbyrsessrsrtvjytjydtwvtvytrva0rte515reteteysersyserytgfrwerwdqqqwryrhw}'
