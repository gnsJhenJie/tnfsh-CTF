# %%
a = '87 101 108 1100011 0157 6d 0145 040 116 0157 100000 0164 104 1100101 32 0123 69 67 0103 1001111 1001110 040 062 060 49 064 100000 0157 110 6c 0151 1101110 101 040 0103 1010100 70 101110 0124 1101000 101 100000 1010011 1000101 67 0103 4f 4e 100000 105 1110011 040 116 1101000 0145 040 1100010 0151 103 103 0145 1110011 0164 100000 1101000 0141 99 6b 1100101 0162 32 0143 111 1101110 1110100 101 0163 0164 040 0151 0156 040 74 0141 1110000 1100001 0156 056 4f 0157 0160 115 44 040 0171 1101111 117 100000 1110111 0141 0156 1110100 32 0164 6f 32 6b 1101110 1101111 1110111 100000 0164 1101000 0145 040 0146 6c 97 1100111 2c 100000 0144 111 110 100111 116 100000 1111001 6f 117 63 0110 1100101 0162 0145 100000 1111001 111 117 100000 97 114 0145 46 1010011 0105 0103 67 79 1001110 123 87 110011 110001 67 110000 1001101 32 55 060 100000 110111 0110 110011 32 53 51 0103 0103 060 0116 040 5a 0117 73 0101 7d 1001000 0141 1110110 1100101 100000 102 0165 0156 33'
lst = a.split(' ')

# %%
print(chr(int('060',12)))
# Out:
# H

# %%
tmp = str()
ans = str()
for i in lst:
  if len(i)==2:
    tmp = chr(int(i))
  elif len(i)==7:
    tmp = chr(int(i,2))
  elif len(i)==
      try:
          tmp = chr(int(i,8))
      except:
        try:
          tmp = chr(int(i,12))
        except:
          try:
            tmp = chr(int(i,16))
          except:
            pass
  ans+=tmp
ans
# Out:
# 'Wel\U0010c8eb\x9dm\x91(t\x9d𘚠¤h\U0010c945 {ECg\U000f4697\U000f4696(><1@𘚠\x9dnl\x97\U0010cd36e(g\U000f69b4F\U00018af6|\U0010ccc8e𘚠\U000f695b\U000f42a5CgON𘚠i\U0010effb(t\U0010ccc8\x91(\U0010c8ea\x97gg\x91\U0010effb¤𘚠\U0010ccc8\x8dcS\U0010c945¢ \x8fo\U0010cd36\U0010f054e£¤(\x97\x9c(J\x8d\U0010eff0\U0010c8e1\x9c8O\x9d\xa0s,(«\U0010cd37u𘚠\U0010f05f\x8d\x9c\U0010f054 ¤o S\U0010cd36\U0010cd37\U0010f05f𘚠¤\U0010ccc8\x91(\x92la\U0010c94f,𘚠\x90on𘜏t𘚠\U0010f3d9ou?n\U0010c945¢\x91𘚠\U0010f3d9ou𘚠ar\x91.\U000f695bigCO\U000f4696{W\U0001adbb\U0001adb1C\U0001adb0\U000f468d 7<𘚠\U0001ae1fn\U0001adbb 53gg<t(FuIe}\U000f4628\x8d\U0010f05e\U0010c945𘚠f¥\x9c!'

# %%
print(chr(int('6c',16)))
# Out:
# l
